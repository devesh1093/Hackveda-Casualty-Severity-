# %%
import pandas as pd

data=pd.read_csv("https://raw.githubusercontent.com/devesh1093/Hackveda-Casualty-Severity-/main/Accident_Dataset_prepared.csv")

# %%
#Computing pairwise correlation of all variables,
data.corr()
# Out:
#                      Number of Vehicles  ...  Type of Vehicle
# Number of Vehicles             1.000000  ...        -0.017832
# Road Surface                  -0.017588  ...         0.038361
# Lighting Conditions           -0.042863  ...         0.016449
# Weather Conditions             0.004567  ...         0.040406
# Casualty Victim               -0.410351  ...         0.294168
# Casualty Severity             -0.122205  ...        -0.147896
# Sex of Casualty                0.027725  ...         0.220732
# Age of Casualty                0.046023  ...         0.150059
# Type of Vehicle               -0.017832  ...         1.000000
#
# [9 rows x 9 columns]

# %%
data.drop("1st Road Class", axis=1,inplace=True)

# %%
data.head()
# Out:
#    Number of Vehicles  Road Surface  ...  Age of Casualty  Type of Vehicle
# 0                   5             3  ...               36                6
# 1                   5             3  ...               27                6
# 2                   1             2  ...               68                4
# 3                   2             1  ...               49                4
# 4                   2             2  ...               33                4
#
# [5 rows x 9 columns]

# %%
#Checking th shape of data and print rows and columns
print("Our Data has %d rows and %d columns"% data.shape)
# Out:
# Our Data has 2664 rows and 9 columns

# %%
#Check the contents of data table
data
#Get top three rows of the data
data.head(3)
#Get bottom three rows of the data
data.tail(3)
# Out:
#       Number of Vehicles  Road Surface  ...  Age of Casualty  Type of Vehicle
# 2661                   2             1  ...               23                4
# 2662                   1             1  ...               76                4
# 2663                   2             1  ...               55                2
#
# [3 rows x 9 columns]

# %%
#show the columns
data.columns
# Out:
# Index(['Number of Vehicles', 'Road Surface', 'Lighting Conditions',
#        'Weather Conditions', 'Casualty Victim', 'Casualty Severity',
#        'Sex of Casualty', 'Age of Casualty', 'Type of Vehicle'],
#       dtype='object')

# %%
data["Number of Vehicles"]
data["Age of Casualty"]
# Out:
# 0       36
# 1       27
# 2       68
# 3       49
# 4       33
#         ..
# 2659     4
# 2660    23
# 2661    23
# 2662    76
# 2663    55
# Name: Age of Casualty, Length: 2664, dtype: int64

# %%
#Extracting multiple columns
data[['Number of Vehicles', 'Road Surface', 'Lighting Conditions','Type of Vehicle']]
# Out:
#       Number of Vehicles  Road Surface  Lighting Conditions  Type of Vehicle
# 0                      5             3                    1                6
# 1                      5             3                    1                6
# 2                      1             2                    2                4
# 3                      2             1                    1                4
# 4                      2             2                    1                4
# ...                  ...           ...                  ...              ...
# 2659                   3             2                    2                4
# 2660                   2             1                    2                4
# 2661                   2             1                    2                4
# 2662                   1             1                    2                4
# 2663                   2             1                    2                2
#
# [2664 rows x 4 columns]

# %%
#Extract unique values from the columns
data["Number of Vehicles"].unique()
# Out:
# array([5, 1, 2, 3, 6, 4, 7])

# %%
#Create graphs in python using matplotlib
import matplotlib.pyplot as plt

# %%
data["Number of Vehicles"].plot(kind="bar")

# %%
data.plot("Number of Vehicles",kind="bar")

# %%
plt.scatter(data["Number of Vehicles"],data["Casualty Severity"])
plt.title("Compare number of vehicles with casualty severity")
plt.xlabel("Number of Vehicles")
plt.ylabel("Casualty Severity")
# Out:
# Text(0, 0.5, 'Casualty Severity')

# %%
#Mathematical operations on number of Vehicles
print("Max number of vehicles",data["Number of Vehicles"].max())
print("Min number of vehicles",data["Number of Vehicles"].min())
print("Mean of number of vehicles",round(data["Number of Vehicles"].mean()))
print("Count the number of rows in number of vehicles",data["Number of Vehicles"].count())
# Out:
# Max number of vehicles 7
# Min number of vehicles 1
# Mean of number of vehicles 2
# Count the number of rows in number of vehicles 2664

# %%
data["Number of Vehicles"].describe()
# Out:
# count    2664.000000
# mean        1.952703
# std         0.803214
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         7.000000
# Name: Number of Vehicles, dtype: float64

# %%
data.corr()
# Out:
#                      Number of Vehicles  ...  Type of Vehicle
# Number of Vehicles             1.000000  ...        -0.017832
# Road Surface                  -0.017588  ...         0.038361
# Lighting Conditions           -0.042863  ...         0.016449
# Weather Conditions             0.004567  ...         0.040406
# Casualty Victim               -0.410351  ...         0.294168
# Casualty Severity             -0.122205  ...        -0.147896
# Sex of Casualty                0.027725  ...         0.220732
# Age of Casualty                0.046023  ...         0.150059
# Type of Vehicle               -0.017832  ...         1.000000
#
# [9 rows x 9 columns]
